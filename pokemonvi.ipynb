# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objs as go

# %%
pk=pd.read_csv(r"C:\Users\91902\Documents\my course\pokemon.csv")
pk
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49  \
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
pk.head() # From Stating top 5
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49  \
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
pk.tail() # From ending last 5
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense
# 795  719              Diancie     Rock  Fairy    600  50     100      150  \
# 796  719  DiancieMega Diancie     Rock  Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True

# %%
pk.columns #Columns Name
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
pk.drop('#',axis=1,inplace=True) # delete Full columns

# %%
pk.columns
# Out:
# Index(['Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
pk['Name']
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
pk.isnull().sum() #check total null Value
# Out:
# Name            0
# Type 1          0
# Type 2        386
# Total           0
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
pk.shape
# Out:
# (800, 12)

# %%
pk.dropna() #delete null value
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense
# 0                Bulbasaur    Grass  Poison    318  45      49       49  \
# 1                  Ivysaur    Grass  Poison    405  60      62       63
# 2                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 6                Charizard     Fire  Flying    534  78      84       78
# ..                     ...      ...     ...    ...  ..     ...      ...
# 795                Diancie     Rock   Fairy    600  50     100      150
# 796    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
pk.shape # check number of columns and Row
# Out:
# (800, 12)

# %%
pk['Name'][6] ="pikacho" # change name in columns
# Out:
# C:\Users\91902\AppData\Local\Temp\ipykernel_12332\2108686140.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pk['Name'][6] ="pikacho" # change name in columns

# %%
pk.head(10)
# Out:
#                         Name Type 1  Type 2  Total  HP  Attack  Defense
# 0                  Bulbasaur  Grass  Poison    318  45      49       49  \
# 1                    Ivysaur  Grass  Poison    405  60      62       63
# 2                   Venusaur  Grass  Poison    525  80      82       83
# 3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4                 Charmander   Fire     NaN    309  39      52       43
# 5                 Charmeleon   Fire     NaN    405  58      64       58
# 6                    pikacho   Fire  Flying    534  78      84       78
# 7  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# ...

# %%
pk['Generation'][3] =0 #Change Value
# Out:
# C:\Users\91902\AppData\Local\Temp\ipykernel_12332\839029757.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pk['Generation'][3] =0 #Change Value

# %%
pk.head()
# Out:
#                     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk
# 0              Bulbasaur  Grass  Poison    318  45      49       49       65  \
# 1                Ivysaur  Grass  Poison    405  60      62       63       80
# 2               Venusaur  Grass  Poison    525  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# 4             Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           0      False
# 4       50     65           1      False

# %%
pk.tail(10)
# Out:
#                     Name   Type 1  Type 2  Total   HP  Attack  Defense
# 790               Noibat   Flying  Dragon    245   40      30       35  \
# 791              Noivern   Flying  Dragon    535   85      70       80
# 792              Xerneas    Fairy     NaN    680  126     131       95
# 793              Yveltal     Dark  Flying    680  126     131       95
# 794     Zygarde50% Forme   Dragon  Ground    600  108     100      121
# 795              Diancie     Rock   Fairy    600   50     100      150
# 796  DiancieMega Diancie     Rock   Fairy    700   50     160      110
# 797  HoopaHoopa Confined  Psychic   Ghost    600   80     110       60
# 798   HoopaHoopa Unbound  Psychic    Dark    680   80     160       60
# 799            Volcanion     Fire   Water    600   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 790       45       40     55           6      False
# 791       97       80    123           6      False
# ...

# %%
pk.head(8)
# Out:
#                         Name Type 1  Type 2  Total  HP  Attack  Defense
# 0                  Bulbasaur  Grass  Poison    318  45      49       49  \
# 1                    Ivysaur  Grass  Poison    405  60      62       63
# 2                   Venusaur  Grass  Poison    525  80      82       83
# 3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4                 Charmander   Fire     NaN    309  39      52       43
# 5                 Charmeleon   Fire     NaN    405  58      64       58
# 6                    pikacho   Fire  Flying    534  78      84       78
# 7  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           0      False
# 4       60       50     65           1      False
# ...

# %%
pk.rename(columns={'Name':'pokemon_Name'} ,inplace=True) #to Change columns names

# %%
pk
# Out:
#               pokemon_Name   Type 1  Type 2  Total  HP  Attack  Defense
# 0                Bulbasaur    Grass  Poison    318  45      49       49  \
# 1                  Ivysaur    Grass  Poison    405  60      62       63
# 2                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 795                Diancie     Rock   Fairy    600  50     100      150
# 796    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
pk.columns
# Out:
# Index(['pokemon_Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
pk.drop(['Generation'],axis=1,inplace=True) # Delete columns axix1 mean full lenght of column Inplace True mean Save

# %%
pk.columns
# Out:
# Index(['pokemon_Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Legendary'],
#       dtype='object')

# %%
sns.histplot(pk,x='Type 1',color='cyan')
# Out:
# <Axes: xlabel='Type 1', ylabel='Count'>

# %%
sns.barplot(pk,x='pokemon_Name', y='Sp. Atk')
# Out:
# <Axes: xlabel='pokemon_Name', ylabel='Sp. Atk'>

# %%
px.scatter(pk,x='pokemon_Name', y='Sp. Atk',color='pokemon_Name')

# %%
px.bar(pk,x='pokemon_Name', y='Sp. Atk',color='pokemon_Name',title='Pokemon dataset',
       labels={'pokemon_Name:Catagory','pokemon_Name'},height=1000,width=1200,template='plotly_dark')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 px.bar(pk,x='pokemon_Name', y='Sp. Atk',color='pokemon_Name',title='Pokemon dataset',
#       2        labels={'pokemon_Name:Catagory','pokemon_Name'},height=1000,width=1200,template='plotly_dark')
#
# ...

# %%
pk.isnull().sum()
# Out:
# pokemon_Name      0
# Type 1            0
# Type 2          386
# Total             0
# HP                0
# Attack            0
# Defense           0
# Sp. Atk           0
# Sp. Def           0
# Speed             0
# Legendary         0
# dtype: int64

# %%
a=pk.isnull().sum()
px.bar(a,x=a.index,y=a.values,title='null values',color=a.index,labels={'x':'columns','y':'count'},
       height=00,width=00,template='plotly_dark')

# %%
px.pie(pk,'Type 1',template='plotly_dark', )

# %%
sns.jointplot(pk,x='pokemon_Name', y='Sp. Atk',hue='Type 1')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 sns.jointplot(pk,x='pokemon_Name', y='Sp. Atk',hue='Type 1')
#
# File c:\Users\91902\miniconda3\lib\site-packages\seaborn\axisgrid.py:2265, in jointplot(data, x, y, hue, kind, height, ratio, space, dropna, xlim, ylim, color, palette, hue_order, hue_norm, marginal_ticks, joint_kws, marginal_kws, **kwargs)
#    2262         marginal_kws.setdefault("fill", True)
#    2264     marginal_kws.setdefault("color", color)
# -> 2265     grid.plot_marginals(marg_func, **marginal_kws)
#    2267 elif kind.startswith("hist"):
#    2268
#    2269     # TODO process pair parameters for bins, etc. and pass
#    2270     # to both joint and marginal plots
#    2272     joint_kws.setdefault("color", color)
#
# ...

# %%
pk.columns
# Out:
# Index(['pokemon_Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed'],
#       dtype='object')

# %%
px.bar(pk,x='pokemon_Name', y='Attack',title='Pokemon dataset',
       labels={'pokemon_Name:Catagory','pokemon_Name'},height=1000,width=1200)

# %%
px.bar(pk,x='Type 2',y='Sp. Def',color='Type 2')

# %%
sns.barplot(pk,x='Type 2', y='Sp. Atk',hue='Type 2')
# Out:
# <Axes: xlabel='Type 2', ylabel='Sp. Atk'>

# %%
pk.isnull().sum()
# Out:
# pokemon_Name      0
# Type 1            0
# Type 2          386
# Total             0
# HP                0
# Attack            0
# Defense           0
# Sp. Atk           0
# Sp. Def           0
# Speed             0
# dtype: int64

# %%
pk.dropna(),
# Out:
#               pokemon_Name   Type 1  Type 2  Total  HP  Attack  Defense
# 0                Bulbasaur    Grass  Poison    318  45      49       49  \
# 1                  Ivysaur    Grass  Poison    405  60      62       63
# 2                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 6                  pikacho     Fire  Flying    534  78      84       78
# ..                     ...      ...     ...    ...  ..     ...      ...
# 795                Diancie     Rock   Fairy    600  50     100      150
# 796    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed
# 0         65       65     45
# 1         80       80     60
# ...

# %%
px.pie(pk,'Type 2',template='plotly_dark', )

# %%
pk.describe()
# Out:
#            Total          HP      Attack     Defense     Sp. Atk     Sp. Def
# count  800.00000  800.000000  800.000000  800.000000  800.000000  800.000000  \
# mean   435.10250   69.258750   79.001250   73.842500   72.820000   71.902500
# std    119.96304   25.534669   32.457366   31.183501   32.722294   27.828916
# min    180.00000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    330.00000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    450.00000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    515.00000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    780.00000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed
# count  800.000000
# mean    68.277500
# std     29.060474
# min      5.000000
# 25%     45.000000
# 50%     65.000000
# 75%     90.000000
# max    180.000000

# %%
pk.info
# Out:
# <bound method DataFrame.info of               pokemon_Name   Type 1  Type 2  Total  HP  Attack  Defense
# 0                Bulbasaur    Grass  Poison    318  45      49       49  \
# 1                  Ivysaur    Grass  Poison    405  60      62       63
# 2                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 795                Diancie     Rock   Fairy    600  50     100      150
# 796    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Legendary
# ...

# %%
pk.columns
# Out:
# Index(['pokemon_Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Legendary'],
#       dtype='object')

# %%
pk.loc[:,['pokemon_Name','Type 1']]
# Out:
#               pokemon_Name   Type 1
# 0                Bulbasaur    Grass
# 1                  Ivysaur    Grass
# 2                 Venusaur    Grass
# 3    VenusaurMega Venusaur    Grass
# 4               Charmander     Fire
# ..                     ...      ...
# 795                Diancie     Rock
# 796    DiancieMega Diancie     Rock
# 797    HoopaHoopa Confined  Psychic
# 798     HoopaHoopa Unbound  Psychic
# 799              Volcanion     Fire
#
# [800 rows x 2 columns]

# %%
pk.loc[[1,2],:]
# Out:
#   pokemon_Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def
# 1      Ivysaur  Grass  Poison    405  60      62       63       80       80  \
# 2     Venusaur  Grass  Poison    525  80      82       83      100      100
#
#    Speed  Legendary
# 1     60      False
# 2     80      False

# %%
pk.iloc[0:3,0:2]
# Out:
#   pokemon_Name Type 1
# 0    Bulbasaur  Grass
# 1      Ivysaur  Grass
# 2     Venusaur  Grass

# %%
pk.head()
# Out:
#             pokemon_Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk
# 0              Bulbasaur  Grass  Poison    318  45      49       49       65  \
# 1                Ivysaur  Grass  Poison    405  60      62       63       80
# 2               Venusaur  Grass  Poison    525  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# 4             Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Legendary
# 0       65     45      False
# 1       80     60      False
# 2      100     80      False
# 3      120     80      False
# 4       50     65      False

# %%
pk.drop([1,2],axis=0)
# Out:
#               pokemon_Name   Type 1  Type 2  Total  HP  Attack  Defense
# 0                Bulbasaur    Grass  Poison    318  45      49       49  \
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# 5               Charmeleon     Fire     NaN    405  58      64       58
# 6                  pikacho     Fire  Flying    534  78      84       78
# ..                     ...      ...     ...    ...  ..     ...      ...
# 795                Diancie     Rock   Fairy    600  50     100      150
# 796    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Legendary
# 0         65       65     45      False
# ...
