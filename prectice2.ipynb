# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import plotly.express as px
import plotly.graph_objs as go

# %%
dt=pd.read_csv('Car_sales.csv')
dt
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value
# 0          Acura  Integra              16.919               16.360  \
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase
# 0      Passenger               21.50          1.8       140.0      101.2  \
# ...

# %%
dt.head(15)
# Out:
#    Manufacturer        Model  Sales_in_thousands  __year_resale_value
# 0         Acura      Integra              16.919               16.360  \
# 1         Acura           TL              39.384               19.875
# 2         Acura           CL              14.114               18.225
# 3         Acura           RL               8.588               29.725
# 4          Audi           A4              20.397               22.255
# 5          Audi           A6              18.780               23.555
# 6          Audi           A8               1.380               39.000
# 7           BMW         323i              19.747                  NaN
# 8           BMW         328i               9.231               28.675
# 9           BMW         528i              17.527               36.125
# 10        Buick      Century              91.561               12.475
# 11        Buick        Regal              39.350               13.740
# ...

# %%
dt.tail()
# Out:
#     Manufacturer Model  Sales_in_thousands  __year_resale_value Vehicle_type
# 152        Volvo   V40               3.545                  NaN    Passenger  \
# 153        Volvo   S70              15.245                  NaN    Passenger
# 154        Volvo   V70              17.531                  NaN    Passenger
# 155        Volvo   C70               3.493                  NaN    Passenger
# 156        Volvo   S80              18.969                  NaN    Passenger
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length
# 152                24.4          1.9       160.0      100.5   67.6   176.6  \
# 153                27.5          2.4       168.0      104.9   69.3   185.9
# 154                28.8          2.4       168.0      104.9   69.3   186.2
# 155                45.5          2.3       236.0      104.9   71.5   185.7
# 156                36.0          2.9       201.0      109.9   72.1   189.8
#
# ...

# %%
dt.columns
# Out:
# Index(['Manufacturer', 'Model', 'Sales_in_thousands', '__year_resale_value',
#        'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity',
#        'Fuel_efficiency', 'Latest_Launch', 'Power_perf_factor'],
#       dtype='object')

# %%
dt.columns.tolist()
# Out:
# ['Manufacturer',
#  'Model',
#  'Sales_in_thousands',
#  '__year_resale_value',
#  'Vehicle_type',
#  'Price_in_thousands',
#  'Engine_size',
#  'Horsepower',
#  'Wheelbase',
#  'Width',
#  'Length',
#  'Curb_weight',
#  'Fuel_capacity',
#  'Fuel_efficiency',
#  'Latest_Launch',
#  'Power_perf_factor']

# %%
dt.describe()
# Out:
#        Sales_in_thousands  __year_resale_value  Price_in_thousands
# count          157.000000           121.000000          155.000000  \
# mean            52.998076            18.072975           27.390755
# std             68.029422            11.453384           14.351653
# min              0.110000             5.160000            9.235000
# 25%             14.114000            11.260000           18.017500
# 50%             29.450000            14.180000           22.799000
# 75%             67.956000            19.875000           31.947500
# max            540.561000            67.550000           85.500000
#
#        Engine_size  Horsepower   Wheelbase       Width      Length
# count   156.000000  156.000000  156.000000  156.000000  156.000000  \
# mean      3.060897  185.948718  107.487179   71.150000  187.343590
# std       1.044653   56.700321    7.641303    3.451872   13.431754
# min       1.000000   55.000000   92.600000   62.600000  149.400000
# ...

# %%
dt.describe(include='all')
# Out:
#        Manufacturer Model  Sales_in_thousands  __year_resale_value
# count           157   157          157.000000           121.000000  \
# unique           30   156                 NaN                  NaN
# top           Dodge  Neon                 NaN                  NaN
# freq             11     2                 NaN                  NaN
# mean            NaN   NaN           52.998076            18.072975
# std             NaN   NaN           68.029422            11.453384
# min             NaN   NaN            0.110000             5.160000
# 25%             NaN   NaN           14.114000            11.260000
# 50%             NaN   NaN           29.450000            14.180000
# 75%             NaN   NaN           67.956000            19.875000
# max             NaN   NaN          540.561000            67.550000
#
#        Vehicle_type  Price_in_thousands  Engine_size  Horsepower   Wheelbase
# count           157          155.000000   156.000000  156.000000  156.000000  \
# ...

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales_in_thousands   157 non-null    float64
#  3   __year_resale_value  121 non-null    float64
#  4   Vehicle_type         157 non-null    object
#  5   Price_in_thousands   155 non-null    float64
#  6   Engine_size          156 non-null    float64
#  7   Horsepower           156 non-null    float64
#  8   Wheelbase            156 non-null    float64
#  9   Width                156 non-null    float64
#  10  Length               156 non-null    float64
#  11  Curb_weight          155 non-null    float64
#  12  Fuel_capacity        156 non-null    float64
#  13  Fuel_efficiency      154 non-null    float64
#  14  Latest_Launch        157 non-null    object
# ...

# %%
dt.shape
# Out:
# (157, 16)

# %%
dt.head(20)
# Out:
#    Manufacturer        Model  Sales_in_thousands  __year_resale_value
# 0         Acura      Integra              16.919               16.360  \
# 1         Acura           TL              39.384               19.875
# 2         Acura           CL              14.114               18.225
# 3         Acura           RL               8.588               29.725
# 4          Audi           A4              20.397               22.255
# 5          Audi           A6              18.780               23.555
# 6          Audi           A8               1.380               39.000
# 7           BMW         323i              19.747                  NaN
# 8           BMW         328i               9.231               28.675
# 9           BMW         528i              17.527               36.125
# 10        Buick      Century              91.561               12.475
# 11        Buick        Regal              39.350               13.740
# ...

# %%
dt.iloc[9]
# Out:
# Manufacturer                  BMW
# Model                        528i
# Sales_in_thousands         17.527
# __year_resale_value        36.125
# Vehicle_type            Passenger
# Price_in_thousands           38.9
# Engine_size                   2.8
# Horsepower                  193.0
# Wheelbase                   111.4
# Width                        70.9
# Length                      188.0
# Curb_weight                 3.472
# Fuel_capacity                18.5
# Fuel_efficiency              25.0
# Latest_Launch          04-04-2011
# Power_perf_factor       83.998724
# Name: 9, dtype: object

# %%
dt.iloc[[7,9,10,11]]
# Out:
#    Manufacturer    Model  Sales_in_thousands  __year_resale_value
# 7           BMW     323i              19.747                  NaN  \
# 9           BMW     528i              17.527               36.125
# 10        Buick  Century              91.561               12.475
# 11        Buick    Regal              39.350               13.740
#
#    Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase
# 7     Passenger              26.990          2.5       170.0      107.3  \
# 9     Passenger              38.900          2.8       193.0      111.4
# 10    Passenger              21.975          3.1       175.0      109.0
# 11    Passenger              25.300          3.8       240.0      109.0
#
#     Width  Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch
# 7    68.4   176.0        3.179           16.6             26.0     6/28/2011  \
# 9    70.9   188.0        3.472           18.5             25.0    04-04-2011
# ...

# %%
dt['Fuel_capacity']
# Out:
# 0      13.2
# 1      17.2
# 2      17.2
# 3      18.0
# 4      16.4
#        ...
# 152    15.8
# 153    17.9
# 154    17.9
# 155    18.5
# 156    21.1
# Name: Fuel_capacity, Length: 157, dtype: float64

# %%
dt[['Price_in_thousands', 'Engine_size', 'Horsepower',
       'Wheelbase', 'Width']]
# Out:
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width
# 0                 21.50          1.8       140.0      101.2   67.3
# 1                 28.40          3.2       225.0      108.1   70.3
# 2                   NaN          3.2       225.0      106.9   70.6
# 3                 42.00          3.5       210.0      114.6   71.4
# 4                 23.99          1.8       150.0      102.6   68.2
# ..                  ...          ...         ...        ...    ...
# 152               24.40          1.9       160.0      100.5   67.6
# 153               27.50          2.4       168.0      104.9   69.3
# 154               28.80          2.4       168.0      104.9   69.3
# 155               45.50          2.3       236.0      104.9   71.5
# 156               36.00          2.9       201.0      109.9   72.1
#
# [157 rows x 5 columns]

# %%
dt.iloc[:9]
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type
# 0        Acura  Integra              16.919               16.360    Passenger  \
# 1        Acura       TL              39.384               19.875    Passenger
# 2        Acura       CL              14.114               18.225    Passenger
# 3        Acura       RL               8.588               29.725    Passenger
# 4         Audi       A4              20.397               22.255    Passenger
# 5         Audi       A6              18.780               23.555    Passenger
# 6         Audi       A8               1.380               39.000    Passenger
# 7          BMW     323i              19.747                  NaN    Passenger
# 8          BMW     328i               9.231               28.675    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length
# 0               21.50          1.8       140.0      101.2   67.3   172.4  \
# ...

# %%
dt.iloc[3:7,[2,3,4]]
# Out:
#    Sales_in_thousands  __year_resale_value Vehicle_type
# 3               8.588               29.725    Passenger
# 4              20.397               22.255    Passenger
# 5              18.780               23.555    Passenger
# 6               1.380               39.000    Passenger

# %%
col_to_see=['Price_in_thousands', 'Engine_size', 'Horsepower',
       'Wheelbase', 'Width']
dt[col_to_see]
# Out:
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width
# 0                 21.50          1.8       140.0      101.2   67.3
# 1                 28.40          3.2       225.0      108.1   70.3
# 2                   NaN          3.2       225.0      106.9   70.6
# 3                 42.00          3.5       210.0      114.6   71.4
# 4                 23.99          1.8       150.0      102.6   68.2
# ..                  ...          ...         ...        ...    ...
# 152               24.40          1.9       160.0      100.5   67.6
# 153               27.50          2.4       168.0      104.9   69.3
# 154               28.80          2.4       168.0      104.9   69.3
# 155               45.50          2.3       236.0      104.9   71.5
# 156               36.00          2.9       201.0      109.9   72.1
#
# [157 rows x 5 columns]

# %%
dt.Sales_in_thousands
# Out:
# 0      16.919
# 1      39.384
# 2      14.114
# 3       8.588
# 4      20.397
#         ...
# 152     3.545
# 153    15.245
# 154    17.531
# 155     3.493
# 156    18.969
# Name: Sales_in_thousands, Length: 157, dtype: float64

# %%
dt.Sales_in_thousands.unique()
# Out:
# array([1.69190e+01, 3.93840e+01, 1.41140e+01, 8.58800e+00, 2.03970e+01,
#        1.87800e+01, 1.38000e+00, 1.97470e+01, 9.23100e+00, 1.75270e+01,
#        9.15610e+01, 3.93500e+01, 2.78510e+01, 8.32570e+01, 6.37290e+01,
#        1.59430e+01, 6.53600e+00, 1.11850e+01, 1.47850e+01, 1.45519e+02,
#        1.35126e+02, 2.46290e+01, 4.25930e+01, 2.64020e+01, 1.79470e+01,
#        3.22990e+01, 2.18550e+01, 1.07995e+02, 7.85400e+00, 3.27750e+01,
#        3.11480e+01, 3.23060e+01, 1.34620e+01, 5.34800e+01, 3.06960e+01,
#        7.60340e+01, 4.73400e+00, 7.11860e+01, 8.80280e+01, 9.16000e-01,
#        2.27061e+02, 1.67670e+01, 3.10380e+01, 1.11313e+02, 1.01323e+02,
#        1.81749e+02, 7.02270e+01, 1.13369e+02, 3.50680e+01, 2.45815e+02,
#        1.75670e+02, 6.34030e+01, 2.76747e+02, 1.55787e+02, 1.25338e+02,
#        2.20650e+02, 5.40561e+02, 1.99685e+02, 2.30902e+02, 7.32030e+01,
#        1.28550e+01, 7.60290e+01, 4.11840e+01, 6.66920e+01, 2.94500e+01,
# ...

# %%
team_dt = dt.groupby('Manufacturer').get_group('Audi')
team_dt
# Out:
#   Manufacturer Model  Sales_in_thousands  __year_resale_value Vehicle_type
# 4         Audi    A4              20.397               22.255    Passenger  \
# 5         Audi    A6              18.780               23.555    Passenger
# 6         Audi    A8               1.380               39.000    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length
# 4               23.99          1.8       150.0      102.6   68.2   178.0  \
# 5               33.95          2.8       200.0      108.7   76.1   192.0
# 6               62.00          4.2       310.0      113.0   74.0   198.2
#
#    Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch
# 4        2.998           16.4             27.0    10-08-2011  \
# 5        3.561           18.5             22.0    08-09-2011
# 6        3.902           23.7             21.0     2/27/2012
#
#    Power_perf_factor
# 4          62.777639
# 5          84.565105
# 6         134.656858

# %%
dt.plot(kind='bar',x='Sales_in_thousands',y='Price_in_thousands',color='red',title='sales vs price',figsize=(13,10))
# Out:
# <Axes: title={'center': 'sales vs price'}, xlabel='Sales_in_thousands'>

# %%
sns.histplot(dt,x='Sales_in_thousands',bins=15,kde=True)
# Out:
# <Axes: xlabel='Sales_in_thousands', ylabel='Count'>

# %%
fig,ax=plt.subplots(figsize=(8,4))
sns.histplot(dt,x='Sales_in_thousands', bins=15,kde=True,ax=ax,color='red')
plt . savefig('histogram.png',dpi=1000)

# %%
sns.color_palette('rainbow')
# Out:
# [(0.21764705882352942, 0.42912060877260894, 0.9755119679804366),
#  (0.0725490196078431, 0.7829276104921027, 0.9005867023006374),
#  (0.3549019607843137, 0.9741386021045101, 0.7829276104921028),
#  (0.6450980392156862, 0.9741386021045102, 0.622112816721474),
#  (0.9274509803921569, 0.7829276104921029, 0.43467642176596505),
#  (1.0, 0.42912060877260916, 0.2199463578396687)]

# %%
sns.set_palette('rainbow')
fig,ax=plt.subplots(figsize=(8,8),ncols=2,nrows=2)
sns.histplot(dt,x='Sales_in_thousands',bins=15,kde=True,ax=ax[0,0],color='red')
sns.histplot(dt,x='__year_resale_value',bins=15,kde=True,ax=ax[0,1],color='blue')
sns.histplot(dt,x='Price_in_thousands',bins=15,kde=True,ax=ax[1,0],color='green')
sns.histplot(dt,x='Engine_size',bins=15,kde=True,ax=ax[1,1],color='yellow')
# Out:
# <Axes: xlabel='Engine_size', ylabel='Count'>

# %%
dt.isnull().sum()
# Out:
# Manufacturer            0
# Model                   0
# Sales_in_thousands      0
# __year_resale_value    36
# Vehicle_type            0
# Price_in_thousands      2
# Engine_size             1
# Horsepower              1
# Wheelbase               1
# Width                   1
# Length                  1
# Curb_weight             2
# Fuel_capacity           1
# Fuel_efficiency         3
# Latest_Launch           0
# Power_perf_factor       2
# dtype: int64

# %%
dt.isnull().sum().plot(kind='bar',figsize=(10,5))
# Out:
# <Axes: >

# %%
a=dt.isnull().sum()
px.bar(a,x=a.index,y=a.values,title='Missing Value',color=a.index,labels={'x':'Columns','y':'Count'},
       height=400,width=800,template='plotly_dark')

# %%
sns.barplot(dt,x='Engine_size',y='Sales_in_thousands',)
# Out:
# <Axes: xlabel='Engine_size', ylabel='Sales_in_thousands'>

# %%
sns.scatterplot(dt,x='Sales_in_thousands',y='Price_in_thousands')
# Out:
# <Axes: xlabel='Sales_in_thousands', ylabel='Price_in_thousands'>

# %%
sns.scatterplot(dt,x='Sales_in_thousands',y='Price_in_thousands',hue='Model',palette='rainbow')
# Out:
# <Axes: xlabel='Sales_in_thousands', ylabel='Price_in_thousands'>

# %%
sns.jointplot(dt,x='Sales_in_thousands',y='Price_in_thousands',hue='Model',palette='rainbow')

# %%
sns.set_palette('husl')
sns.jointplot(dt,x='Sales_in_thousands',y='Price_in_thousands',palette='rainbow',kind='hex')

# %%
px.scatter(dt,x='Sales_in_thousands',y='Price_in_thousands',color='Model')

# %%
px.bar(dt,x='Model',y='Sales_in_thousands',color='Model',title= 'Car salesdataset',
       labels={'Model:Catagory','Sales_in_thousands'},height=400,width=600,template='plotly_dark')
